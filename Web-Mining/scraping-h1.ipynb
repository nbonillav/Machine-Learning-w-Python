# %% [markdown]
# ## Tarea 1
# Programa Experto en Inteligencia Artificial con Python
# ML3006 - Web Mining en Python
# Estudiante: Natalia Bonilla Villalobos.

# %% [markdown]
# <a id="menu"></a>
#
# # Menú
# - [Ejercicio 1](#ej1)
# - [Ejercicio 2](#ej2)

# %%
# !pip install lxml
# !pip install html5lib
# !pip install beautifulsoup4

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from io import StringIO
import pandas as pd
import numpy as np

# %% [markdown]
# <a id="ej1"></a>
# # Ejercicio 1
#
# [50 puntos] Extracción de datos de cantones de Costa Rica
#
# En este ejercicio deberá extraer información sobre los cantones de Costa Rica desde Wikipedia. Visite: https://es.wikipedia.org/wiki/Anexo:Cantones_de_Costa_Rica
#
# Su tarea consiste en:
#
# - a) [15 puntos] Descargar la página y extraer sus tablas HTML utilizando `requests` y `pandas` (o `BeautifulSoup`, si fuera necesario).
# **Pista**: Use `pd.read_html()` para extraer tablas HTML. Busque tablas con la clase CSS wikitable.
# - b) [20 puntos] Identificar y extraer la tabla principal que contiene la información de los cantones. La tabla final debe incluir, como mínimo, columnas equivalentes a provincia, cantón, ciudad cabecera, año de creación, área y población.
# **Pista**: No todas las tablas son útiles. Implemente una función que verifique si una tabla contiene las columnas esperadas (busque palabras clave como cantón, provincia).
# - c) [10 puntos] Realizar limpieza básica de los datos: eliminar filas completamente vacías, normalizar nombres de columnas y dejar la tabla lista para análisis en pandas.
# - d) [5 puntos] Guardar el resultado final en un archivo CSV llamado `cantones_cr.csv`.
#
# Notas importantes:
# - Use headers HTTP apropiados para evitar bloqueos del servidor.
# - La tabla resultante debe tener aproximadamente 80+ filas (cantones).
# - Maneje posibles excepciones y errores de conexión.
# - Entregue una solución reproducible: el código debe permitir regenerar el CSV a partir de la página indicada.
#
# [↑ Volver al Menú](#menu)

# %% [markdown]
# ## Parte 1
# - a) [15 puntos] Descargar la página y extraer sus tablas HTML utilizando `requests` y `pandas` (o `BeautifulSoup`, si fuera necesario).
#
#     **Pista:** Use `pd.read_html()` para extraer tablas HTML. Busque tablas con la clase CSS wikitable.

# %%
url = 'https://es.wikipedia.org/wiki/Anexo:Cantones_de_Costa_Rica'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})

webpage = urlopen(req).read()
# convertir bytes -> texto usando UTF-8
html = webpage.decode("utf-8")

pagina = BeautifulSoup(webpage, 'html.parser')
print(pagina.title.string)
# Out:
# Anexo:Cantones de Costa Rica - Wikipedia, la enciclopedia libre

# %% [markdown]
# ## Parte 2
# - b) [20 puntos] Identificar y extraer la tabla principal que contiene la información de los cantones. La tabla final debe incluir, como mínimo, columnas equivalentes a provincia, cantón, ciudad cabecera, año de creación, área y población.
#
#     **Pista:** No todas las tablas son útiles. Implemente una función que verifique si
# una tabla contiene las columnas esperadas (busque palabras clave como cantón,
# provincia).

# %%
# table class=wikitable sortable jquery-tablesorter
# Provincia, Canton, Ciudad Cabecera, año de creación, área y población
etqTable = pagina.find("table", {'class':'wikitable sortable'})
print(etqTable)
print(etqTable.text.strip())
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th rowspan="2">Provincia
# </th>
# <th colspan="2" rowspan="2"><big>Cantón</big>
# </th>
# <th rowspan="2"><small>Ciudad<br/>Cabecera</small>
# </th>
# <th rowspan="2"><small>Año de<br/>creación</small>
# </th>
# <th rowspan="2"><small>Área<br/>(km²)</small>
# </th>
# <th rowspan="2"><small>Altitud<br/>(m.s.n.m)</small>
# </th>
# <th colspan="3"><small>Población</small>
# </th>
# <th rowspan="2"><small><a href="/wiki/%C3%8Dndice_de_desarrollo_humano" title="Índice de desarrollo humano">IDH</a><br/>2020</small>
# </th>
# <th colspan="2"><small>Alcalde 2024-2028</small>
# </th></tr>
# <tr>
# <th><small><abbr title="Estimación del INEC con los datos parciales del censo 2022">Est. 2022</abbr></small>
# </th>
# <th><small><abbr title="Densidad de habitantes por km², estimada por el INEC con los datos parciales del censo 2022">Est. Dens. 2022</abbr></small>
# </th>
# <th><small><a href="/wiki/Censo_costarricense_de_2011" title="Censo costarricense de 2011">Censo 2011</a></small>
# </th>
# <th><small>Partido</small>
# </th>
# <th><small>Nombre</small>
# </th></tr>
# <tr>
# <td data-sort-value="1" rowspan="20"><span style="display:none;">San José</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_de_la_Provincia_de_San_Jos%C3%A9.svg" title="Bandera de Provincia de San José"><img alt="Bandera de Provincia de San José" class="mw-file-element" data-file-height="500" data-file-width="750" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Bandera_de_la_Provincia_de_San_Jos%C3%A9.svg/20px-Bandera_de_la_Provincia_de_San_Jos%C3%A9.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Bandera_de_la_Provincia_de_San_Jos%C3%A9.svg/40px-Bandera_de_la_Provincia_de_San_Jos%C3%A9.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Provincia_de_San_Jos%C3%A9" title="Provincia de San José">San José</a>
# </td>
# <td align="center" data-sort-value="San José"><span class="shieldicon"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Blason_de_San_Jos%C3%A9_(Costa_Rica).svg" title="Escudo de Cantón de San José"><img alt="Escudo de Cantón de San José" class="mw-file-element" data-file-height="1209" data-file-width="945" decoding="async" height="38" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Blason_de_San_Jos%C3%A9_%28Costa_Rica%29.svg/40px-Blason_de_San_Jos%C3%A9_%28Costa_Rica%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Blason_de_San_Jos%C3%A9_%28Costa_Rica%29.svg/60px-Blason_de_San_Jos%C3%A9_%28Costa_Rica%29.svg.png 1.5x" width="30"/></a></span></span>
# </td>
# <td><span style="display:none;">Cantón de San José</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_de_San_Jos%C3%A9_(Costa_Rica).svg" title="Bandera de Cantón de San José"><img alt="Bandera de Cantón de San José" class="mw-file-element" data-file-height="700" data-file-width="1100" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Bandera_de_San_Jos%C3%A9_%28Costa_Rica%29.svg/20px-Bandera_de_San_Jos%C3%A9_%28Costa_Rica%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Bandera_de_San_Jos%C3%A9_%28Costa_Rica%29.svg/40px-Bandera_de_San_Jos%C3%A9_%28Costa_Rica%29.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Cant%C3%B3n_de_San_Jos%C3%A9" title="Cantón de San José">San José</a>
# </td>
# <td><small><a href="/wiki/San_Jos%C3%A9_(Costa_Rica)" title="San José (Costa Rica)">San José</a></small>
# </td>
# <td align="right">1848
# </td>
# <td align="right">44,62
# </td>
# <td align="right">1137
# </td>
# <td align="right">352 381
# </td>
# <td align="right">7897,38
# </td>
# <td align="right">288 054
# </td>
# <td align="right" bgcolor="DCFFC3">0,758
# </td>
# <td><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_Partido_Juntos_SJO_Costa_Rica_(2023-Presente).svg"><img class="mw-file-element" data-file-height="256" data-file-width="512" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/Bandera_Partido_Juntos_SJO_Costa_Rica_%282023-Presente%29.svg/20px-Bandera_Partido_Juntos_SJO_Costa_Rica_%282023-Presente%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/Bandera_Partido_Juntos_SJO_Costa_Rica_%282023-Presente%29.svg/40px-Bandera_Partido_Juntos_SJO_Costa_Rica_%282023-Presente%29.svg.png 1.5x" width="20"/></a></span><small> <a href="/wiki/Partidos_cantonales_de_Costa_Rica" title="Partidos cantonales de Costa Rica"><abbr title="Juntos San José">PJSJ</abbr></a></small>
# </td>
# <td data-sort-value="Miranda Méndez"><small>Luis Diego Miranda Méndez</small>
# </td></tr>
# <tr>
# <td align="center" data-sort-value="Escazú"><span class="shieldicon"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Escudo_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg" title="Escudo de Cantón de Escazú"><img alt="Escudo de Cantón de Escazú" class="mw-file-element" data-file-height="910" data-file-width="687" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Escudo_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg/40px-Escudo_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Escudo_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg/60px-Escudo_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg.png 1.5x" width="30"/></a></span></span>
# </td>
# <td><span style="display:none;">Cantón de Escazú</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg" title="Bandera de Cantón de Escazú"><img alt="Bandera de Cantón de Escazú" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Bandera_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg/20px-Bandera_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Bandera_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg/40px-Bandera_Cant%C3%B3n_Escaz%C3%BA_Costa_Rica.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Cant%C3%B3n_de_Escaz%C3%BA" title="Cantón de Escazú">Escazú</a>
# </td>
# <td><small><a class="mw-redirect" href="/wiki/Escaz%C3%BA_(Costa_Rica)" title="Escazú (Costa Rica)">Escazú</a></small>
# </td>
# <td align="right">1848
# </td>
# <td align="right">34,53
# </td>
# <td align="right">1129
# </td>
# <td align="right">71 500
# </td>
# <td align="right">2070,66
# </td>
# <td align="right">56 509
# </td>
# <td align="right" bgcolor="A4FFA9">0,867
# </td>
# <td><small><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_Partido_Nueva_Generaci%C3%B3n_Costa_Rica.svg"><img class="mw-file-element" data-file-height="171" data-file-width="512" decoding="async" height="7" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Bandera_Partido_Nueva_Generaci%C3%B3n_Costa_Rica.svg/20px-Bandera_Partido_Nueva_Generaci%C3%B3n_Costa_Rica.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Bandera_Partido_Nueva_Generaci%C3%B3n_Costa_Rica.svg/40px-Bandera_Partido_Nueva_Generaci%C3%B3n_Costa_Rica.svg.png 1.5x" width="20"/></a></span> <a href="/wiki/Partido_Nueva_Generaci%C3%B3n" title="Partido Nueva Generación">PNG</a></small>
# </td>
# <td data-sort-value="Umaña Umaña"><small>Orlando Esteban Umaña Umaña</small>
# </td></tr>
# <tr>
# <td align="center" data-sort-value="Desamparados"><span class="shieldicon"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Escudo_del_cant%C3%B3n_de_Desamparados.svg" title="Escudo de Cantón de Desamparados"><img alt="Escudo de Cantón de Desamparados" class="mw-file-element" data-file-height="998" data-file-width="687" decoding="async" height="44" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Escudo_del_cant%C3%B3n_de_Desamparados.svg/40px-Escudo_del_cant%C3%B3n_de_Desamparados.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Escudo_del_cant%C3%B3n_de_Desamparados.svg/60px-Escudo_del_cant%C3%B3n_de_Desamparados.svg.png 1.5x" width="30"/></a></span></span>
# </td>
# <td><span style="display:none;">Cantón de Desamparados</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_de_Desamparados.svg" title="Bandera de Cantón de Desamparados"><img alt="Bandera de Cantón de Desamparados" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Bandera_de_Desamparados.svg/20px-Bandera_de_Desamparados.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Bandera_de_Desamparados.svg/40px-Bandera_de_Desamparados.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Cant%C3%B3n_de_Desamparados" title="Cantón de Desamparados">Desamparados</a>
# </td>
# <td><small><a href="/wiki/Desamparados_(Costa_Rica)" title="Desamparados (Costa Rica)">Desamparados</a></small>
# </td>
# <td align="right">1862
# </td>
# <td align="right">118,89
# </td>
# <td align="right">1270
# </td>
# <td align="right">223 226
# </td>
# <td align="right">1877,58
# </td>
# <td align="right">208 411
# </td>
# <td align="right" bgcolor="DCFFC3">0,743
# </td>
# <td><small><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_de_Partido_Liberaci%C3%B3n_Nacional.svg"><img class="mw-file-element" data-file-height="307" data-file-width="512" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Bandera_de_Partido_Liberaci%C3%B3n_Nacional.svg/20px-Bandera_de_Partido_Liberaci%C3%B3n_Nacional.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Bandera_de_Partido_Liberaci%C3%B3n_Nacional.svg/40px-Bandera_de_Partido_Liberaci%C3%B3n_Nacional.svg.png 1.5x" width="20"/></a></span> <a href="/wiki/Partido_Liberaci%C3%B3n_Nacional" title="Partido Liberación Nacional">PLN</a></small>
# </td>
# <td data-sort-value="Naranjo Brenes"><small>María Antonieta Naranjo Brenes</small>
# </td></tr>
# <tr>
# <td align="center" data-sort-value="Puriscal"><span class="shieldicon"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Escudo_del_cant%C3%B3n_de_Puriscal.svg" title="Escudo de Cantón de Puriscal"><img alt="Escudo de Cantón de Puriscal" class="mw-file-element" data-file-height="960" data-file-width="790" decoding="async" height="36" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Escudo_del_cant%C3%B3n_de_Puriscal.svg/40px-Escudo_del_cant%C3%B3n_de_Puriscal.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e8/
><span class="shieldicon"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Escudo_del_Cant%C3%B3n_de_Turrubares.png" title="Escudo de Cantón de Turrubares"><img alt="Escudo de Cantón de Turrubares" class="mw-file-element" data-file-height="705" data-file-width="592" decoding="async" height="36" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Escudo_del_Cant%C3%B3n_de_Turrubares.png/40px-Escudo_del_Cant%C3%B3n_de_Turrubares.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Escudo_del_Cant%C3%B3n_de_Turrubares.png/60px-Escudo_del_Cant%C3%B3n_de_Turrubares.png 1.5x" width="30"/></a></span></span>
# </td>
# <td><span style="display:none;">Cantón de Turrubares</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_de_Turrubares_(Costa_Rica).svg" title="Bandera de Cantón de Turrubares"><img alt="Bandera de Cantón de Turrubares" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/28/Bandera_de_Turrubares_%28Costa_Rica%29.svg/20px-Bandera_de_Turrubares_%28Costa_Rica%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/28/Bandera_de_Turrubares_%28Costa_Rica%29.svg/40px-Bandera_de_Turrubares_%28Costa_Rica%29.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Cant%C3%B3n_de_Turrubares" title="Cantón de Turrubares">Turrubares</a>
# </td>
# <td><small><a href="/wiki/San_Pablo_de_Turrubares" title="San Pablo de Turrubares">San Pablo</a></small>
# </td>
# <td align="right">1920
# </td>
# <td align="right">416,25
# </td>
# <td align="right">313
# </td>
# <td align="right">6173
# </td>
# <td align="right">14,83
# </td>
# <td align="right">5512
# </td>
# <td align="right" bgcolor="DCFFC3">0,712
# </td>
# <td><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_Partido_Unidos_Podemos_CR.svg"><img class="mw-file-element" data-file-height="256" data-file-width="512" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Bandera_Partido_Unidos_Podemos_CR.svg/20px-Bandera_Partido_Unidos_Podemos_CR.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Bandera_Partido_Unidos_Podemos_CR.svg/40px-Bandera_Partido_Unidos_Podemos_CR.svg.png 1.5x" width="20"/></a></span><small> <a href="/wiki/Unidos_Podemos_(Costa_Rica)" title="Unidos Podemos (Costa Rica)">UP</a></small>
# </td>
# <td data-sort-value="Vargas Calderón"><small>Martín Vargas Calderón</small>
# </td></tr>
# <tr>
# <td align="center" data-sort-value="Dota"><span class="shieldicon"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Escudo_del_Cant%C3%B3n_de_Dota.svg" title="Escudo de Cantón de Dota"><img alt="Escudo de Cantón de Dota" class="mw-file-element" data-file-height="1741" data-file-width="1240" decoding="async" height="42" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/Escudo_del_Cant%C3%B3n_de_Dota.svg/40px-Escudo_del_Cant%C3%B3n_de_Dota.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/Escudo_del_Cant%C3%B3n_de_Dota.svg/60px-Escudo_del_Cant%C3%B3n_de_Dota.svg.png 1.5x" width="30"/></a></span></span>
# </td>
# <td><span style="display:none;">Cantón de Dota</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_Canton_de_Dota.svg" title="Bandera de Cantón de Dota"><img alt="Bandera de Cantón de Dota" class="mw-file-element" data-file-height="500" data-file-width="750" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Bandera_Canton_de_Dota.svg/20px-Bandera_Canton_de_Dota.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Bandera_Canton_de_Dota.svg/40px-Bandera_Canton_de_Dota.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Cant%C3%B3n_de_Dota" title="Cantón de Dota">Dota</a>
# </td>
# <td><small><a href="/wiki/Santa_Mar%C3%ADa_de_Dota" title="Santa María de Dota">Santa María</a></small>
# </td>
# <td align="right">1925
# </td>
# <td align="right">404,44
# </td>
# <td align="right">1874
# </td>
# <td align="right">9364
# </td>
# <td align="right">23,15
# </td>
# <td align="right">6948
# </td>
# <td align="right" bgcolor="FFFDC3">0,660
# </td>
# ...
# </td>
# <td><small><a href="/wiki/Matina" title="Matina">Matina</a></small>
# </td>
# <td align="right">1969
# </td>
# <td align="right">770,4
# </td>
# <td align="right">13
# </td>
# <td align="right">45 329
# </td>
# <td align="right">58,84
# </td>
# <td align="right">37 721
# </td>
# <td align="right" bgcolor="FFFDC3">0,579
# </td>
# <td><small><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_del_Partido_Unidad_Social_Cristiana.svg"><img class="mw-file-element" data-file-height="256" data-file-width="512" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Bandera_del_Partido_Unidad_Social_Cristiana.svg/20px-Bandera_del_Partido_Unidad_Social_Cristiana.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Bandera_del_Partido_Unidad_Social_Cristiana.svg/40px-Bandera_del_Partido_Unidad_Social_Cristiana.svg.png 1.5x" width="20"/></a></span> <a href="/wiki/Partido_Unidad_Social_Cristiana" title="Partido Unidad Social Cristiana">PUSC</a></small>
# </td>
# <td data-sort-value="Céspedes Salazar"><small><a href="/wiki/W%C3%A1lter_C%C3%A9spedes_Salazar" title="Wálter Céspedes Salazar">Wálter Céspedes Salazar</a></small>
# </td></tr>
# <tr>
# <td align="center" data-sort-value="Guácimo"><span class="shieldicon">[[Archivo:|30px|Escudo de Cantón de Guácimo]]</span>
# </td>
# <td><span style="display:none;">Cantón de Guácimo</span><span class="flagicon"><span class="mw-image-border notpageimage noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_de_Gu%C3%A1cimo_(Costa_Rica).svg" title="Bandera de Cantón de Guácimo"><img alt="Bandera de Cantón de Guácimo" class="mw-file-element" data-file-height="307" data-file-width="512" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f0/Bandera_de_Gu%C3%A1cimo_%28Costa_Rica%29.svg/20px-Bandera_de_Gu%C3%A1cimo_%28Costa_Rica%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f0/Bandera_de_Gu%C3%A1cimo_%28Costa_Rica%29.svg/40px-Bandera_de_Gu%C3%A1cimo_%28Costa_Rica%29.svg.png 1.5x" width="20"/></a></span> </span><a href="/wiki/Cant%C3%B3n_de_Gu%C3%A1cimo" title="Cantón de Guácimo">Guácimo</a>
# </td>
# <td><small><a href="/wiki/Gu%C3%A1cimo_(Costa_Rica)" title="Guácimo (Costa Rica)">Guácimo</a></small>
# </td>
# <td align="right">1971
# </td>
# <td align="right">801,56
# </td>
# <td align="right">67
# </td>
# <td align="right">49 606
# </td>
# <td align="right">61,89
# </td>
# <td align="right">41 266
# </td>
# <td align="right" bgcolor="FFFDC3">0,676
# </td>
# <td><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bandera_Partido_Justicia_Social_Costarricense_Costa_Rica.svg"><img class="mw-file-element" data-file-height="256" data-file-width="512" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Bandera_Partido_Justicia_Social_Costarricense_Costa_Rica.svg/20px-Bandera_Partido_Justicia_Social_Costarricense_Costa_Rica.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Bandera_Partido_Justicia_Social_Costarricense_Costa_Rica.svg/40px-Bandera_Partido_Justicia_Social_Costarricense_Costa_Rica.svg.png 1.5x" width="20"/></a></span> <small><abbr title="Justicia Social Costarricense">PJSC</abbr></small>
# </td>
# <td data-sort-value="Mora Valverde"><small>Beatriz Mora Valverde</small>
# </td></tr></tbody></table>
# Provincia
#
# Cantón
#
# CiudadCabecera
#
# Año decreación
#
# Área(km²)
#
# Altitud(m.s.n.m)
#
# Población
#
# IDH2020
#
# Alcalde 2024-2028
#
#
# Est. 2022
#
# Est. Dens. 2022
#
# Censo 2011
#
# Partido
#
# Nombre
#
#
# San José San José
#
#
#
# Cantón de San José San José
#
# San José
#
# 1848
#
# 44,62
#
# 1137
#
# 352 381
#
# 7897,38
#
# 288 054
#
# 0,758
#
#  PJSJ
#
# Luis Diego Miranda Méndez
#
#
#
#
# Cantón de Escazú Escazú
#
# Escazú
#
# 1848
#
# 34,53
#
# 1129
#
# 71 500
#
# 2070,66
#
# 56 509
#
# 0,867
#
#  PNG
#
# Orlando Esteban Umaña Umaña
#
#
#
#
# Cantón de Desamparados Desamparados
#
# Desamparados
#
# 1862
#
# 118,89
#
# 1270
#
# 223 226
#
# 1877,58
#
# 208 411
#
# 0,743
#
#  PLN
#
# María Antonieta Naranjo Brenes
#
#
#
#
# Cantón de Puriscal Puriscal
#
# Santiago
#
# 1868
#
# 555,04
#
# 945
#
# 38 525
#
# 69,41
#
# 33 004
#
# 0,755
#
#  PLN
#
# Iris Cristina Arroyo Hererra
#
#
#
#
# Cantón de Tarrazú Tarrazú
#
# San Marcos
#
# 1868
#
# 291,27
#
# 1471
#
# 17 810
#
# 61,15
#
# 16 280
#
# 0,668
#
#  PUSC
#
# Fernando Portuguez Parra
#
#
#
#
# Cantón de Aserrí Aserrí
#
# Aserrí
#
# 1882
#
# 168,26
#
# 1373
#
# 59 588
#
# 354,14
#
# 57 892
#
# 0,737
#
#  PLN
#
# Patricia Mayela Porras Segura
#
#
#
#
# Cantón de Mora Mora
#
# Colón
#
# 1883
#
# 163,48
#
# 807
#
# 32 348
#
# 197,87
#
# 26 294
#
# 0,801
#
#  PLP
#
# Rodrigo Alfonso Jiménez Cascante
#
#
#
#
# Cantón de Goicoechea Goicoechea
#
# Guadalupe
#
# 1891
#
# 31,7
#
# 1364
#
# 132 104
#
# 4167,32
#
# 115 084
#
# 0,758
#
#  PLN
#
# Fernando Miguel Chavarría Quirós
#
#
#
#
# Cantón de Santa Ana (Costa Rica) Santa Ana
#
# Santa Ana
#
# 1907
#
# 61,42
#
# 904
#
# 58 020
#
# 944,64
#
# 49 123
#
# 0,871
#
#  PUSC
#
# Juan José Vargas Fallas
#
#
#
#
# Cantón de Alajuelita Alajuelita
#
# Alajuelita
#
# 1909
#
# 21,47
#
# 1194
#
# 81 012
#
# 3773,27
#
# 77 603
#
# 0,712
#
#  PNG
#
# María del Rosario Siles Fernández[a]​
#
#
#
#
# Cantón de Vázquez de Coronado Vázquez de Coronado
#
# San Isidro
#
# 1910
#
# 223,93
#
# 1414
#
# 67 078
#
# 299,55
#
# 60 486
#
# 0,801
#
#  PLN
#
# Yamilet Quesada Zúñiga
#
#
#
#
# Cantón de Acosta Acosta
#
# San Ignacio
#
# 1910
#
# 342,56
#
# 1009
#
# 22 542
#
# 65,8
#
# 20 209
#
# 0,731
#
#  PLN
#
# Nelson Martín Umaña Quirós
#
#
#
#
# Cantón de Tibás Tibás
#
# San Juan
#
# 1914
#
# 8,27
#
# 1140
#
# 74 592
#
# 9019,59
#
# 64 842
#
# 0,766
#
#  PLN
#
# José Alejandro Alvarado Vega
#
#
#
#
# Cantón de Moravia Moravia
#
# San Vicente
#
# 1914
#
# 28,82
#
# 1297
#
# 59 546
#
# 2066,13
#
# 56 919
#
# 0,835
#
#  SM
#
# Diego Armando López López
#
#
#
#
# Cantón de Montes de Oca Montes de Oca
#
# San Pedro
#
# 1915
#
# 15,78
#
# 1262
#
# 53 862
#
# 3413,31
#
# 49 132
#
# 0,857
#
#  PUSC
#
# Domingo Argüello García
#
#
#
#
# Cantón de Turrubares Turrubares
#
# San Pablo
#
# 1920
#
# 416,25
#
# 313
#
# 6173
#
# 14,83
#
# 5512
#
# 0,712
#
#  UP
#
# Martín Vargas Calderón
#
#
#
#
# Cantón de Dota Dota
#
# Santa María
#
# 1925
#
# 404,44
#
# 1874
#
# 9364
#
# 23,15
#
# 6948
#
# 0,660
#
#  PUSC
#
# Adrián Cordero Cordero
#
#
#
#
# Cantón de Curridabat Curridabat
#
# Curridabat
#
# 1929
#
# 16,06
#
# 1244
#
# 71 026
#
# 4422,54
#
# 65 206
#
# 0,835
#
#  CSXXI
#
# Errol Andrés Solano Bolaños
#
#
#
#
# Cantón de Pérez Zeledón Pérez Zeledón
#
# San Isidro de El General
#
# 1931
#
# 1901,08
#
# 690
#
# 156 917
#
# 82,54
#
# 134 534
#
# 0,746
#
#  PUSC
#
# Emanuel Ceciliano Alfaro
#
#
#
#
# Cantón de León Cortés Castro León Cortés Castro
#
# San Pablo
#
# 1962
#
# 121,9
#
# 1620
#
# 13 553
#
# 111,18
#
# 12 200
#
# 0,690
#
#  FA
#
# Juan Manuel Quirós Sánchez
#
#
# Alajuela Alajuela
#
#
#
# Cantón de Alajuela Alajuela
#
# Alajuela
#
# 1848
#
# 391,61
#
# 942
#
# 322 143
#
# 822,61
#
# 254 886
#
# 0,784
#
#  PLN
#
# Roberto Hernán Thompson Chacón
#
#
#
#
# Cantón de San Ramón San Ramón
#
# San Ramón
#
# 1856
#
# 1021,75
#
# 974
#
# 93 264
#
# 91,28
#
# 80 566
#
# 0,754
#
#  PUSC
#
# María Gabriela Jiménez Corrales
#
#
#
#
# Cantón de Grecia Grecia
#
# Grecia
#
# 1867
#
# 142,47
#
# 1025
#
# 76 226
#
# 535,03
#
# 76 898
#
# 0,777
#
#  UP
#
# Donald Alberto Quesada Rodríguez
#
#
# [[Archivo:|30px|Escudo de Cantón de San Mateo]]
#
# Cantón de San Mateo San Mateo
#
# San Mateo
#
# 1868
#
# 125,03
#
# 311
#
# 6952
#
# 55,6
#
# 6136
#
# 0,675
#
#  PLN
#
# Karen Tatiana Alfaro Jiménez
#
#
#
#
# Cantón de Atenas Atenas
#
# Atenas
#
# 1868
#
# 126,32
#
# 706
#
# 30 407
#
# 240,71
#
# 25 460
#
# 0,772
#
#  PSD
#
# Wilberth Martín Aguilar Gatjens
#
#
#
#
# Cantón de Naranjo Naranjo
#
# Naranjo
#
# 1886
#
# 127,03
#
# 1121
#
# 46 647
#
# 367,21
#
# 42 713
#
# 0,763
#
#  PLN
#
# Randall Vega Blanco
#
#
#
#
# Cantón de Palmares Palmares
#
# Palmares
#
# 1888
#
# 38,94
#
# 1028
#
# 39 148
#
# 1005,34
#
# 34 716
#
# 0,761
#
#  PPP
#
# José Andrés Vargas Rodríguez
#
#
# [[Archivo:|30px|Escudo de Cantón de Poás]]
#
# Cantón de Poás Poás
#
# San Pedro
#
# 1901
#
# 74,48
#
# 1184
#
# 36 207
#
# 486,13
#
# 29 199
#
# 0,766
#
#  PUSC
#
# Heibel Antonio Rodríguez Araya
#
#
#
#
# Cantón de Orotina Orotina
#
# Orotina
#
# 1908
#
# 145,11
#
# 198
#
# 24 217
#
# 166,89
#
# 20 341
#
# 0,736
#
#  PLN
#
# Margot Montero Jiménez
#
#
# [[Archivo:|30px|Escudo de Cantón de San Carlos]]
#
# Cantón de San Carlos San Carlos
#
# Quesada
#
# 1911
#
# 3352,14
#
# 340
#
# 198 742
#
# 59,29
#
# 163 745
#
# 0,765
#
#  PLN
#
# Juan Diego González Picado
#
#
#
#
# Cantón de Zarcero Zarcero
#
# Zarcero
#
# 1915
#
# 157,36
#
# 1777
#
# 15 153
#
# 96,3
#
# 12 205
#
# 0,767
#
#  PLN
#
# Gina María Rodríguez Rojas
#
#
# [[Archivo:|30px|Escudo de Cantón de Sarchí]]
#
# Cantón de Sarchí Sarchí
#
# Sarchí Norte
#
# 1949
#
# 136,77
#
# 1116
#
# 21 562
#
# 157,65
#
# 18 085
#
# 0,739
#
#  APS
#
# Maikol Gerardo Porras Morales
#
#
#
#
# Cantón de Upala Upala
#
# Upala
#
# 1970
#
# 1592,68
#
# 194
#
# 57 361
#
# 36,02
#
# 43 953
#
# 0,678
#
#  PUSC
#
# Aura Yamileth López Obregón
#
#
#
#
# Cantón de Los Chiles Los Chiles
#
# Los Chiles
#
# 1970
#
# 1332,71
#
# 47
#
# 34 701
#
# 26,04
#
# 23 735
#
# 0,640
#
#  PLN
#
# Juan Abel Beteta Ocampos[b]​
#
#
#
#
# Cantón de Guatuso Guatuso
#
# San Rafael
#
# 1970
#
# 752,83
#
# 140
#
# 18 316
#
# 24,33
#
# 15 508
#
# 0,706
#
#  PUSC
#
# Carlos Alberto Sequeira Orozco
#
#
#
#
# Cantón de Río Cuarto Río Cuarto
#
# Río Cuarto
#
# 2018
#
# 254,9
#
# 277
#
# 14 418
#
# 56,56
#
# 11 074[c]​
#
# 0,732
#
#  PLN
#
# José Miguel Jiménez Araya
#
#
# Cartago Cartago
#
#
#
# Cantón de Cartago Cartago
#
# Cartago
#
# 1848
#
# 278,66
#
# 1575
#
# 165 417
#
# 593,62
#
# 147 898
#
# 0,791
#
#  PAY
#
# Mario Redondo Poveda
#
#
# [[Archivo:|30px|Escudo de Cantón de Paraíso]]
#
# Cantón de Paraíso Paraíso
#
# Paraíso
#
# 1848
#
# 477
#
# 1171
#
# 65 941
#
# 138,24
#
# 57 743
#
# 0,778
#
#  UP
#
# Michaell Álvarez Quirós
#
#
#
#
# Cantón de La Unión La Unión
#
# Tres Ríos
#
# 1848
#
# 44,18
#
# 1331
#
# 99 539
#
# 2253,03
#
# 99 399
#
# 0,809
#
#  PLN
#
# Cristian Torres Garita
#
#
# [[Archivo:|30px|Escudo de Cantón de Jiménez]]
#
# Cantón de Jiménez Jiménez
#
#  Juan Viñas
#
# 1903
#
# 250,07
#
# 862
#
# 18 710
#
# 74,82
#
# 14 669
#
# 0,762
#
#  PLN
#
# Ana Isabel Azofeifa Pereira
#
#
# [[Archivo:|30px|Escudo de Cantón de Turrialba]]
#
# Cantón de Turrialba Turrialba
#
# Turrialba
#
# 1903
#
# 1589,24
#
# 768
#
# 82 065
#
# 51,64
#
# 69 616
#
# 0,751
#
#  PNG
#
# Carlos Eduardo Hidalgo Flores
#
#
# [[Archivo:|30px|Escudo de Cantón de Alvarado]]
#
# Cantón de Alvarado Alvarado
#
# Pacayas
#
# 1908
#
# 79,19
#
# 1610
#
# 17 134
#
# 216,37
#
# 14 312
#
# 0,769
#
#  UP
#
# Karol Fabiola Granados Martínez
#
#
#
#
# Cantón de Oreamuno Oreamuno
#
# San Rafael
#
# 1914
#
# 202,89
#
# 1861
#
# 48 911
#
# 241,07
#
# 45 473
#
# 0,764
#
#  UP
#
# Erick Mauricio Jiménez Valverde
#
#
# [[Archivo:|30px|Escudo de Cantón de El Guarco]]
#
# Cantón de El Guarco El Guarco
#
# El Tejar
#
# 1939
#
# 172
#
# 1526
#
# 47 375
#
# 275,44
#
# 41 793
#
# 0,798
#
#  PLN
#
# Víctor Hugo Monestel Tencio
#
#
# Heredia Heredia
#
#
#
# Cantón de Heredia Heredia
#
# Heredia
#
# 1848
#
# 283,12
#
# 1242
#
# 131 901
#
# 465,88
#
# 123 616
#
# 0,816
#
#  PLN
#
# Ángela Ileana Aguilar Vargas
#
#
#
#
# Cantón de Barva Barva
#
# Barva
#
# 1848
#
# 56,02
#
# 1241
#
# 47 699
#
# 851,46
#
# 40 660
#
# 0,804
#
#  PRSC
#
# Jorge Antonio Acuña Prado
#
#
#
#
# Cantón de Santo Domingo (Costa Rica) Santo Domingo
#
# Santo Domingo
#
# 1869
#
# 25,4
#
# 1230
#
# 45 932
#
# 1808,35
#
# 40 072
#
# 0,810
#
#  PLN
#
# Jorge Luis Fonseca Fonseca
#
#
#
#
# Cantón de Santa Bárbara Santa Bárbara
#
# Santa Bárbara
#
# 1882
#
# 52,1
#
# 1177
#
# 39 133
#
# 751,11
#
# 36 243
#
# 0,805
#
#  PLN
#
# Víctor Manuel Hidalgo Solís
#
#
#
#
# Cantón de San Rafael San Rafael
#
# San Rafael
#
# 1885
#
# 48,31
#
# 1343
#
# 48 848
#
# 1011,14
#
# 45 965
#
# 0,805
#
#  PABIRA
#
# Jorge Eduardo Arias Santamaría
#
#
#
#
# Cantón de San Isidro San Isidro
#
# San Isidro
#
# 1905
#
# 26,67
#
# 1337
#
# 22 806
#
# 855,12
#
# 20 633
#
# 0,826
#
#  PAI
#
# Eddie Ramírez Sánchez
#
#
#
#
# Cantón de Belén Belén
#
# San Antonio
#
# 1907
#
# 12,38
#
# 937
#
# 23 759
#
# 1919,14
#
# 21 633
#
# 0,858
#
#  PUSC
#
# Zeneida Chaves Fernández
#
#
#
#
# Cantón de Flores Flores
#
# San Joaquín
#
# 1915
#
# 6,75
#
# 1086
#
# 22 026
#
# 3263,11
#
# 20 037
#
# 0,774
#
#  PLN
#
# Eder José Ramírez Segura
#
#
# [[Archivo:|30px|Escudo de Cantón de San Pablo (Costa Rica)]]
#
# Cantón de San Pablo (Costa Rica) San Pablo
#
# San Pablo
#
# 1961
#
# 8,34
#
# 1168
#
# 29 860
#
# 3580,34
#
# 27 671
#
# 0,833
#
#  PUSC
#
# Bernardo Porras López
#
#
#
#
# Cantón de Sarapiquí Sarapiquí
#
# Puerto Viejo
#
# 1970
#
# 2144,22
#
# 68
#
# 67 153
#
# 31,32
#
# 57 147
#
# 0,688
#
#  PLN
#
# Vanessa Rodríguez Rodríguez
#
#
# Guanacaste Guanacaste
#
# [[Archivo:|30px|Escudo de Cantón de Liberia]]
#
# Cantón de Liberia Liberia
#
# Liberia
#
# 1848
#
# 1442,17
#
# 193
#
# 80 130
#
# 55,56
#
# 62 987
#
# 0,714
#
#  PLN
#
# José Javier Calvo Darcia
#
#
# [[Archivo:|30px|Escudo de Cantón de Nicoya]]
#
# Cantón de Nicoya Nicoya
#
# Nicoya
#
# 1848
#
# 1337,56
#
# 66
#
# 66 268
#
# 49,54
#
# 50 825
#
# 0,703
#
#  LGN
#
# Carlos Armando Martínez Arias
#
#
# [[Archivo:|30px|Escudo de Cantón de Santa Cruz (Costa Rica)]]
#
# Cantón de Santa Cruz (Costa Rica) Santa Cruz
#
# Santa Cruz
#
# 1848
#
# 1320,8
#
# 39
#
# 72 366
#
# 54,79
#
# 55 104
#
# 0,693
#
#  PASC
#
# Jorge Arturo Alfaro Orias
#
#
#
#
# Cantón de Bagaces Bagaces
#
# Bagaces
#
# 1848
#
# 1277,93
#
# 396
#
# 23 709
#
# 18,55
#
# 19 536
#
# 0,687
#
#  PLP
#
# Daniel Alonso González Madrigal
#
#
# [[Archivo:|30px|Escudo de Cantón de Carrillo]]
#
# Cantón de Carrillo Carrillo
#
# Filadelfia
#
# 1877
#
# 599,01
#
# 30
#
# 48 227
#
# 80,51
#
# 37 122
#
# 0,689
#
#  PSD
#
# Diana Cecilia Méndez Masís
#
#
# [[Archivo:|30px|Escudo de Cantón de Cañas]]
#
# Cantón de Cañas Cañas
#
# Cañas
#
# 1878
#
# 687,04
#
# 86
#
# 31 738
#
# 46,2
#
# 26 201
#
# 0,695
#
#  UP
#
# Alexander Elizondo Duarte
#
#
#
#
# Cantón de Abangares Abangares
#
# Las Juntas
#
# 1915
#
# 646,02
#
# 154
#
# 22 211
#
# 34,38
#
# 18 039
#
# 0,717
#
#  UP
#
# Javier Bogantes Castro
#
#
#
#
# Cantón de Tilarán Tilarán
#
# Tilarán
#
# 1923
#
# 669,24
#
# 579
#
# 21 232
#
# 31,73
#
# 19 640
#
# 0,696
#
#  PLN
#
# Katterin Alfaro López
#
#
# [[Archivo:|30px|Escudo de Cantón de Nandayure]]
#
# Cantón de Nandayure Nandayure
#
# Carmona
#
# 1961
#
# 568,14
#
# 215
#
# 11 874
#
# 20,9
#
# 11 121
#
# 0,687
#
#  PUSC
#
# Teddy Osvaldo Zúñiga Sánchez
#
#
# [[Archivo:|30px|Escudo de Cantón de La Cruz]]
#
# Cantón de La Cruz La Cruz
#
# La Cruz
#
# 1969
#
# 1385,4
#
# 226
#
# 26 829
#
# 19,37
#
# 19 181
#
# 0,596
#
#  PNG
#
# Luis Alonso Alan Corea
#
#
#
#
# Cantón de Hojancha Hojancha
#
# Hojancha
#
# 1971
#
# 262,99
#
# 389
#
# 8224
#
# 31,27
#
# 7197
#
# 0,638
#
#  PUSC
#
# Verónica Campos Barrantes
#
#
# Puntarenas Puntarenas
#
#
#
# Cantón de Puntarenas Puntarenas
#
# Puntarenas
#
# 1848
#
# 1816,86
#
# 169
#
# 141 697
#
# 77,99
#
# 115 019
#
# 0,692
#
#  PUSC
#
# Randall Alexis Chavarría Matarrita
#
#
#
#
# Cantón de Esparza Esparza
#
# Esparza
#
# 1851
#
# 217,23
#
# 198
#
# 34 808
#
# 160,24
#
# 28 644
#
# 0,718
#
#  PUSC
#
# Bienvenido Venegas Porras
#
#
#
#
# Cantón de Buenos Aires Buenos Aires
#
# Buenos Aires
#
# 1940
#
# 2382,94
#
# 386
#
# 50 562
#
# 21,22
#
# 45 244
#
# 0,620
#
#  PLN
#
# Ana Margoth Mora Navarro[d]​
#
#
#
#
# Cantón de Montes de Oro Montes de Oro
#
# Miramar
#
# 1915
#
# 247,6
#
# 370
#
# 16 395
#
# 66,22
#
# 12 950
#
# 0,701
#
#  PLN
#
# Anthony Fallas Jiménez
#
#
# [[Archivo:|30px|Escudo de Cantón de Osa]]
#
# Cantón de Osa Osa
#
# Puerto Cortés
#
# 1940
#
# 1932,7
#
# 24
#
# 36 088
#
# 18,67
#
# 29 433
#
# 0,708
#
#  PNR
#
# Mainor Fernando Anchía Angulo
#
#
# [[Archivo:|30px|Escudo de Cantón de Quepos]]
#
# Cantón de Quepos Quepos
#
# Quepos
#
# 1948
#
# 557,85
#
# 36
#
# 32 416
#
# 58,11
#
# 26 861
#
# 0,680
#
#  PUSC
#
# Patricia Mayela Bolaños Murillo
#
#
# [[Archivo:|30px|Escudo de Cantón de Golfito]]
#
# Cantón de Golfito Golfito
#
# Golfito
#
# 1949
#
# 1752,75
#
# 24
#
# 44 086
#
# 25,15
#
# 39 150
#
# 0,729
#
#  PUSC
#
# Freiner William Lara Blanco
#
#
#
#
# Cantón de Coto Brus Coto Brus
#
# San Vito
#
# 1965
#
# 944,22
#
# 955
#
# 46 351
#
# 49,09
#
# 38 453
#
# 0,683
#
#  PUSC
#
# Rafael Ángel Navarro Umaña
#
#
# [[Archivo:|30px|Escudo de Cantón de Parrita]]
#
# Cantón de Parrita Parrita
#
# Parrita
#
# 1971
#
# 483,22
#
# 4
#
# 20 068
#
# 41,53
#
# 16 115
#
# 0,685
#
#  PNR
#
# Roberto Alonso Rímola Real
#
#
#
#
# Cantón de Corredores Corredores
#
# Ciudad Neily
#
# 1973
#
# 623,62
#
# 58
#
# 51 023
#
# 81,82
#
# 41 831
#
# 0,691
#
#  PLN
#
# Yeison Hay Villalobos
#
#
#
#
# Cantón de Garabito Garabito
#
# Jacó
#
# 1980
#
# 316,01
#
# 22
#
# 26 672
#
# 84,4
#
# 17 229
#
# 0,691
#
#  PG
#
# Francisco José González Madrigal
#
#
#
#
# Cantón de Monteverde Monteverde
#
# Santa Elena
#
# 2021
#
# 53,05
#
# 1330
#
# 5386
#
# 98,13
#
# 4155[c]​
#
#
#
#  PRSC
#
# Yeudy Miguel Ramírez Brenes
#
#
#
#
# Cantón de Puerto Jiménez Puerto Jiménez
#
# Puerto Jiménez
#
# 2022
#
# 722,56
#
# 2
#
# 10 644
#
# 17,76
#
# 8789[c]​
#
#
#
#  PLP
#
# Enrique Segnini Saballo
#
#
# Limón Limón
#
#
#
# Cantón de Limón Limón
#
# Limón
#
# 1892
#
# 1769,38
#
# 12
#
# 116 457
#
# 65,82
#
# 94 415
#
# 0,688
#
#  UP
#
# Ana Janniel Matarrita McCalla[e]​
#
#
# [[Archivo:|30px|Escudo de Cantón de Pococí]]
#
# Cantón de Pococí Pococí
#
# Guápiles
#
# 1911
#
# 2188,17
#
# 134
#
# 146 320
#
# 66,87
#
# 125 962
#
# 0,700
#
#  UP
#
# Manuel Hernández Rivera
#
#
# [[Archivo:|30px|Escudo de Cantón de Siquirres]]
#
# Cantón de Siquirres Siquirres
#
# Siquirres
#
# 1911
#
# 855,14
#
# 127
#
# 63 765
#
# 74,57
#
# 56 786
#
# 0,723
#
#  PLN
#
# Randal Black Reid
#
#
# [[Archivo:|30px|Escudo de Cantón de Talamanca]]
#
# Cantón de Talamanca Talamanca
#
# Bribri
#
# 1969
#
# 2792,23
#
# 29
#
# 48 906
#
# 17,52
#
# 30 712
#
# 0,601
#
#  PUSC
#
# Rugeli Morales Rodríguez
#
#
# [[Archivo:|30px|Escudo de Cantón de Matina]]
#
# Cantón de Matina Matina
#
# Matina
#
# 1969
#
# 770,4
#
# 13
#
# 45 329
#
# 58,84
#
# 37 721
#
# 0,579
#
#  PUSC
#
# Wálter Céspedes Salazar
#
#
# [[Archivo:|30px|Escudo de Cantón de Guácimo]]
#
# Cantón de Guácimo Guácimo
#
# Guácimo
#
# 1971
#
# 801,56
#
# 67
#
# 49 606
#
# 61,89
#
# 41 266
#
# 0,676
#
#  PJSC
#
# Beatriz Mora Valverde

# %%
tablas = pd.read_html(StringIO(html))
tablas
# Out:
# [   Provincia                                           Cantón                \
#     Provincia                                           Cantón      Cantón.1
#  0   San José                                              NaN      San José
#  1   San José                                              NaN        Escazú
#  2   San José                                              NaN  Desamparados
#  3   San José                                              NaN      Puriscal
#  4   San José                                              NaN       Tarrazú
#  ..       ...                                              ...           ...
#  79     Limón     [[Archivo:|30px|Escudo de Cantón de Pococí]]        Pococí
#  80     Limón  [[Archivo:|30px|Escudo de Cantón de Siquirres]]     Siquirres
#  81     Limón  [[Archivo:|30px|Escudo de Cantón de Talamanca]]     Talamanca
#  82     Limón     [[Archivo:|30px|Escudo de Cantón de Matina]]        Matina
#  83     Limón    [[Archivo:|30px|Escudo de Cantón de Guácimo]]       Guácimo
#
#     Ciudad Cabecera Año de creación Área (km²) Altitud (m.s.n.m) Población  \
#     Ciudad Cabecera Año de creación Área (km²) Altitud (m.s.n.m) Est. 2022
#  0         San José            1848       4462              1137   352 381
#  1           Escazú            1848       3453              1129    71 500
#  2     Desamparados            1862      11889              1270   223 226
#  3         Santiago            1868      55504               945    38 525
#  4       San Marcos            1868      29127              1471    17 810
#  ..             ...             ...        ...               ...       ...
#  79        Guápiles            1911     218817               134   146 320
#  80       Siquirres            1911      85514               127    63 765
#  81          Bribri            1969     279223                29    48 906
#  82          Matina            1969       7704                13    45 329
#  83         Guácimo            1971      80156                67    49 606
#
#                                IDH 2020 Alcalde 2024-2028  \
#     Est. Dens. 2022 Censo 2011 IDH 2020           Partido
#  0           789738    288 054    758.0              PJSJ
#  1           207066     56 509    867.0               PNG
#  2           187758    208 411    743.0               PLN
#  3             6941     33 004    755.0               PLN
#  4             6115     16 280    668.0              PUSC
#  ..             ...        ...      ...               ...
#  79            6687    125 962    700.0                UP
#  80            7457     56 786    723.0               PLN
#  81            1752     30 712    601.0              PUSC
#  82            5884     37 721    579.0              PUSC
#  83            6189     41 266    676.0              PJSC
#
#
#                              Nombre
#  0        Luis Diego Miranda Méndez
#  1      Orlando Esteban Umaña Umaña
#  2   María Antonieta Naranjo Brenes
#  3     Iris Cristina Arroyo Hererra
#  4         Fernando Portuguez Parra
#  ..                             ...
#  79         Manuel Hernández Rivera
#  80               Randal Black Reid
#  81        Rugeli Morales Rodríguez
#  82         Wálter Céspedes Salazar
#  83           Beatriz Mora Valverde
#
#  [84 rows x 13 columns],
#                          0                                     1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q6173846]

# %%
def es_tabla_cantones(df):
    
    columnas = " ".join([str(c) for c in df.columns]).lower()
    
    if "provincia" in columnas and "cantón" in columnas:
        return True
    
    return False


tabla_cantones = None

for tabla in tablas:
    if es_tabla_cantones(tabla):
        tabla_cantones = tabla
        break

tabla_cantones.head()
# Out:
#   Provincia Cantón               Ciudad Cabecera Año de creación Área (km²)  \
#   Provincia Cantón      Cantón.1 Ciudad Cabecera Año de creación Área (km²)
# 0  San José    NaN      San José        San José            1848       4462
# 1  San José    NaN        Escazú          Escazú            1848       3453
# 2  San José    NaN  Desamparados    Desamparados            1862      11889
# 3  San José    NaN      Puriscal        Santiago            1868      55504
# 4  San José    NaN       Tarrazú      San Marcos            1868      29127
#
#   Altitud (m.s.n.m) Población                            IDH 2020  \
#   Altitud (m.s.n.m) Est. 2022 Est. Dens. 2022 Censo 2011 IDH 2020
# 0              1137   352 381          789738    288 054    758.0
# 1              1129    71 500          207066     56 509    867.0
# 2              1270   223 226          187758    208 411    743.0
# 3               945    38 525            6941     33 004    755.0
# 4              1471    17 810            6115     16 280    668.0
#
#   Alcalde 2024-2028
#             Partido                          Nombre
# 0              PJSJ       Luis Diego Miranda Méndez
# 1               PNG     Orlando Esteban Umaña Umaña
# 2               PLN  María Antonieta Naranjo Brenes
# 3               PLN    Iris Cristina Arroyo Hererra
# 4              PUSC        Fernando Portuguez Parra

# %%
df = tabla_cantones.copy()
df.shape
# Out:
# (84, 13)

# %%
df.columns.tolist()
# Out:
# [('Provincia', 'Provincia'),
#  ('Cantón', 'Cantón'),
#  ('Cantón', 'Cantón.1'),
#  ('Ciudad Cabecera', 'Ciudad Cabecera'),
#  ('Año de creación', 'Año de creación'),
#  ('Área (km²)', 'Área (km²)'),
#  ('Altitud (m.s.n.m)', 'Altitud (m.s.n.m)'),
#  ('Población', 'Est. 2022'),
#  ('Población', 'Est. Dens. 2022'),
#  ('Población', 'Censo 2011'),
#  ('IDH 2020', 'IDH 2020'),
#  ('Alcalde 2024-2028', 'Partido'),
#  ('Alcalde 2024-2028', 'Nombre')]

# %%
df.columns = df.columns.get_level_values(1) # Aplanamos las columnas, eliminacion de multi-index
df.head(3)
# Out:
#   Provincia Cantón      Cantón.1 Ciudad Cabecera  Año de creación  Área (km²)  \
# 0  San José    NaN      San José        San José             1848        4462
# 1  San José    NaN        Escazú          Escazú             1848        3453
# 2  San José    NaN  Desamparados    Desamparados             1862       11889
#
#    Altitud (m.s.n.m) Est. 2022  Est. Dens. 2022 Censo 2011  IDH 2020 Partido  \
# 0               1137   352 381           789738    288 054     758.0    PJSJ
# 1               1129    71 500           207066     56 509     867.0     PNG
# 2               1270   223 226           187758    208 411     743.0     PLN
#
#                            Nombre
# 0       Luis Diego Miranda Méndez
# 1     Orlando Esteban Umaña Umaña
# 2  María Antonieta Naranjo Brenes

# %%
# Eliminacion de columnas que no necesitamos
df = df.drop(columns=['Cantón', 'Altitud (m.s.n.m)','IDH 2020', 'Partido', 'Nombre', 'Est. Dens. 2022','Censo 2011'])
df.sample(5)
# Out:
#    Provincia       Cantón.1 Ciudad Cabecera  Año de creación  Área (km²)  \
# 33  Alajuela     Los Chiles      Los Chiles             1970      133271
# 37   Cartago        Paraíso         Paraíso             1848         477
# 80     Limón      Siquirres       Siquirres             1911       85514
# 47   Heredia  Santa Bárbara   Santa Bárbara             1882         521
# 14  San José  Montes de Oca       San Pedro             1915        1578
#
#    Est. 2022
# 33    34 701
# 37    65 941
# 80    63 765
# 47    39 133
# 14    53 862

# %% [markdown]
# ## Parte 3
# - c) [10 puntos] Realizar limpieza básica de los datos: eliminar filas completamente vacías, normalizar nombres de columnas y dejar la tabla lista para análisis en pandas.

# %%
print(repr(df['Est. 2022'].iloc[0]))
# Out:
# '352\xa0381'

# %%
# limpiar espacios
df.columns = df.columns.str.strip()
df.head(3)
# Out:
#   Provincia      Cantón.1 Ciudad Cabecera  Año de creación  Área (km²)  \
# 0  San José      San José        San José             1848        4462
# 1  San José        Escazú          Escazú             1848        3453
# 2  San José  Desamparados    Desamparados             1862       11889
#
#   Est. 2022
# 0   352 381
# 1    71 500
# 2   223 226

# %%
df = df.dropna(how="all")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Provincia        84 non-null     object
#  1   Cantón.1         84 non-null     object
#  2   Ciudad Cabecera  84 non-null     object
#  3   Año de creación  84 non-null     int64
#  4   Área (km²)       84 non-null     int64
#  5   Est. 2022        84 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 4.1+ KB

# %%
# Eliminacion de caracter espcial \xa0 entre numeros,
# se pasa a sting se eliminan espacios y luego se pasa a int
df['Est. 2022'] = (df['Est. 2022']
                   .astype(str)
                   .str.replace(r"\s+", "", regex=True)
                   .astype(int)
)
df
# Out:
#    Provincia      Cantón.1 Ciudad Cabecera  Año de creación  Área (km²)  \
# 0   San José      San José        San José             1848        4462
# 1   San José        Escazú          Escazú             1848        3453
# 2   San José  Desamparados    Desamparados             1862       11889
# 3   San José      Puriscal        Santiago             1868       55504
# 4   San José       Tarrazú      San Marcos             1868       29127
# ..       ...           ...             ...              ...         ...
# 79     Limón        Pococí        Guápiles             1911      218817
# 80     Limón     Siquirres       Siquirres             1911       85514
# 81     Limón     Talamanca          Bribri             1969      279223
# 82     Limón        Matina          Matina             1969        7704
# 83     Limón       Guácimo         Guácimo             1971       80156
#
#     Est. 2022
# 0      352381
# 1       71500
# 2      223226
# 3       38525
# 4       17810
# ..        ...
# 79     146320
# 80      63765
# 81      48906
# 82      45329
# 83      49606
#
# [84 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Provincia        84 non-null     object
#  1   Cantón.1         84 non-null     object
#  2   Ciudad Cabecera  84 non-null     object
#  3   Año de creación  84 non-null     int64
#  4   Área (km²)       84 non-null     int64
#  5   Est. 2022        84 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 4.1+ KB

# %%
# Renombrar columnas
df = df.rename(columns={'Cantón.1':'Cantón', 'Est. 2022':'Población'})

# %%
# Filas sin datos faltantes
df.isna().sum()
# Out:
# Provincia          0
# Cantón             0
# Ciudad Cabecera    0
# Año de creación    0
# Área (km²)         0
# Población          0
# dtype: int64

# %% [markdown]
# ## Parte 4
# - d) [5 puntos] Guardar el resultado final en un archivo CSV llamado `cantones_cr.csv`.

# %%
df.head(4)
# Out:
#   Provincia        Cantón Ciudad Cabecera  Año de creación  Área (km²)  \
# 0  San José      San José        San José             1848        4462
# 1  San José        Escazú          Escazú             1848        3453
# 2  San José  Desamparados    Desamparados             1862       11889
# 3  San José      Puriscal        Santiago             1868       55504
#
#    Población
# 0     352381
# 1      71500
# 2     223226
# 3      38525

# %%
df.to_csv("cantones_cr.csv", index=False, encoding="utf-8")

# %% [markdown]
# <a id="ej2"></a>
# # Ejercicio 2
#
# [50 puntos] Extracción de tipos de cambio del BCCR En este ejercicio deberá extraer los tipos de cambio de ventanilla del Banco Central
# de Costa Rica. Visite: https://gee.bccr.fi.cr/IndicadoresEconomicos/Cuadros/frmConsultaTCVentanilla.aspx
#
# Su tarea consiste en:
#
# - a) [10 puntos] Descargar la página y extraer sus tablas utilizando requests y pandas.
#     **Pista**: Use `StringIO` con `pd.read_html()` para evitar warnings de futuras versiones.
# - b) [15 puntos] Identificar y extraer la tabla principal de tipos de cambio que contiene las columnas: Tipo de entidad, Entidad autorizada, Compra, Venta, Diferencial cambiario y Última actualización.
#     **Pista**: Busque la tabla con más filas y al menos 6 columnas. Elimine la primera fila si contiene encabezados duplicados.
# - c) [15 puntos] Realizar limpieza y procesamiento de datos:
#     - Corregir problemas de encoding (caracteres como Ãľ, Ãś, etc.).
#     - Llenar valores NaN en Tipo de entidad usando `ffill()`.
#     - Convertir las columnas numéricas (Compra, Venta, Diferencial) dividiéndolas entre 100 para obtener el formato decimal correcto.
#
#     **Pista**: Los números vienen como enteros (p. ej., 49900) y deben convertirse a decimales (p. ej., 499.00).
# - d) [10 puntos] Guardar el resultado final en un archivo CSV llamado `tc_ventanilla_bccr.csv` con codificación UTF-8.
#
# Notas importantes:
# - Configure el encoding de la respuesta HTTP a utf-8.
# - La tabla final debe contener aproximadamente 3540 entidades financieras.
# - Todos los campos de Tipo de entidad deben estar completos (sin NaN).
# - Use User-Agent apropiado en las cabeceras HTTP.
# - Entregue una solución reproducible:
#
# [↑ Volver al Menú](#menu)

# %% [markdown]
# ## Parte 1
# - a) [10 puntos] Descargar la página y extraer sus tablas utilizando requests y pandas.
#     **Pista**: Use `StringIO` con `pd.read_html()` para evitar warnings de futuras versiones.

# %%
# direccion de la pagina
src = 'https://gee.bccr.fi.cr/IndicadoresEconomicos/Cuadros/frmConsultaTCVentanilla.aspx'

# peticion 
req = Request(src, headers={'User-Agent': 'Mozilla/5.0'})
bccr_page = urlopen(req).read()

# convertir bytes -> texto usando UTF-8
html = bccr_page.decode("utf-8")

tipo_de_cambio_en_ventanila = BeautifulSoup(html, 'html.parser')
print(tipo_de_cambio_en_ventanila.title.string)
# Out:
# Tipo de cambio anunciado en ventanilla

# %%
# table id = 'DG'
etqTable = tipo_de_cambio_en_ventanila.find("table", {'id':'DG'})
print(etqTable.text.strip())
# Out:
# Tipo de EntidadEntidad AutorizadaCompraVentaDiferencial CambiarioÚltima Actualización
#
# Bancos públicosBanco de Costa Rica                                                   460,00474,0014,0019/03/2026    08:32 p.m.
#
#  Banco Nacional de Costa Rica                                          459,00473,0014,0020/03/2026    08:35 a.m.
#
#  Banco Popular y de Desarrollo Comunal                                 461,00475,0014,0017/03/2026    01:37 p.m.
#
# Bancos privadosBanco BAC San José S.A.                                               460,00474,0014,0020/03/2026    08:29 a.m.
#
#  Banco BCT S.A.                                                        457,00475,0018,0019/03/2026    12:54 p.m.
#
#  Banco Cathay de Costa Rica S.A.                                       460,00472,5012,5019/03/2026    12:57 p.m.
#
#  Banco CMB                                                             452,00476,0024,0020/03/2026    09:34 a.m.
#
#  Banco Davivienda (Costa Rica) S.A                                     457,00475,0018,0019/03/2026    02:01 p.m.
#
#  Banco General (Costa Rica) S.A.                                       457,00473,0016,0019/03/2026    12:54 p.m.
#
#  Banco Improsa S.A.                                                    458,00476,0018,0017/03/2026    11:21 a.m.
#
#  Banco Lafise S.A.                                                     456,00474,0018,0020/03/2026    09:01 a.m.
#
#  Banco Promérica S.A.                                                  456,00474,0018,0019/03/2026    05:19 p.m.
#
#  DAVIBANK de Costa Rica S.A.                                           456,00474,0018,0020/03/2026    08:59 a.m.
#
# FinancierasFinanciera Cafsa S.A.                                                 457,00475,0018,0019/03/2026    06:33 p.m.
#
#  Financiera Comeca S.A.                                                456,00476,0020,0020/03/2026    10:03 a.m.
#
#  Financiera MultiMoney S.A.                                            464,00471,507,5019/03/2026    02:12 p.m.
#
# Mutuales de ViviendaGrupo Mutual Alajuela - La Vivienda de Ahorro y Préstamo              459,00474,0015,0019/03/2026    02:15 p.m.
#
#  Mutual Cartago de Ahorro y Préstamo                                   460,00474,0014,0018/03/2026    01:23 p.m.
#
# CooperativasCoope-ANDE N°1 R.L.                                                   462,00476,5014,5019/03/2026    08:55 a.m.
#
#  Coopecaja R.L.                                                        461,00475,0014,0016/03/2026    05:14 p.m.
#
#  Coopemep R.L.                                                         459,00473,0014,0019/03/2026    03:18 p.m.
#
#  Cooperativa  COOCIQUE R.L.                                            457,00475,0018,0020/03/2026    12:29 a.m.
#
#  Cooperativa Coopealianza R.L.                                         459,00475,0016,0019/03/2026    05:42 p.m.
#
#  Cooperativa CREDECOOP R.L.                                            457,00475,0018,0020/03/2026    07:59 a.m.
#
#  Cooperativa Nacional de Educadores R.L. (COOPENAE)                    461,00474,0013,0019/03/2026    03:17 p.m.
#
#  Cooperativa San Marcos R.L.                                           463,00476,0013,0017/03/2026    10:06 a.m.
#
# Casas de CambioAirpak Casa de Cambio                                                 464,00481,0017,0019/03/2026    02:51 p.m.
#
#  ARI Casa de Cambio Internacional S.A.                                 464,44470,315,8720/03/2026    10:35 a.m.
#
#  Casa de Cambio Cambia con Wiz Limitada                                395,00555,00160,0016/03/2026    09:47 a.m.
#
#  Casa de Cambio Global Exchange                                        387,49558,93171,4419/03/2026    09:02 p.m.
#
#  Casa de Cambio Teledolar S. A.                                        463,00481,0018,0020/03/2026    12:40 a.m.
#
# Puestos de BolsaBCT Valores, Puesto De Bolsa, S.A.                                    457,00475,0018,0019/03/2026    01:00 p.m.
#
#  BN Valores S.A., Puesto de Bolsa                                      459,00473,0014,0020/03/2026    08:34 a.m.
#
#  Mercado Valores de Costa Rica Puesto de Bolsa                         457,00475,0018,0020/03/2026    08:21 a.m.
#
#  PB Inversiones SAMA                                                   459,00473,0014,0020/03/2026    07:54 a.m.
#
#  Popular Valores, Puesto de Bolsa                                      461,00475,0014,0018/03/2026    09:11 a.m.
#
#  PRIVAL Securities Puesto de Bolsa S.A                                 459,00473,0014,0019/03/2026    04:42 p.m.

# %% [markdown]
# ## Parte 2
# - b) [15 puntos] Identificar y extraer la tabla principal de tipos de cambio que contiene las columnas: Tipo de entidad, Entidad autorizada, Compra, Venta, Diferencial cambiario y Última actualización.
#
#     **Pista**: Busque la tabla con más filas y al menos 6 columnas. Elimine la primera fila si contiene encabezados duplicados.

# %%
tabla = etqTable.find("table")

# %%
tipo_de_cambio = pd.read_html(StringIO(str(etqTable)))[0]

# %%
tipo_de_cambio.shape
# Out:
# (39, 6)

# %%
tipo_de_cambio.head(4)
# Out:
#                  0                                      1       2      3  \
# 0  Tipo de Entidad                     Entidad Autorizada  Compra  Venta
# 1  Bancos públicos                    Banco de Costa Rica   46000  47400
# 2              NaN           Banco Nacional de Costa Rica   45900  47300
# 3              NaN  Banco Popular y de Desarrollo Comunal   46100  47500
#
#                        4                      5
# 0  Diferencial Cambiario   Última Actualización
# 1                   1400  19/03/2026 08:32 p.m.
# 2                   1400  20/03/2026 08:35 a.m.
# 3                   1400  17/03/2026 01:37 p.m.

# %%
print(tipo_de_cambio.iloc[0,0].encode())
# Out:
# b'Tipo de Entidad'

# %%
tipo_de_cambio.isna().sum()
# Out:
# 0    31
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# dtype: int64

# %%
# se copia el conjunto de datos original en otr avariable
df = tipo_de_cambio.copy()

# %%
# Se asignar la primera fila (0) como nombres de columnas
df.columns = df.iloc[0]
# Se liminar la primera fila (que ahora es el cabecera)
df = df.drop(df.index[0])
# Reiniciar el index para que comience en 0
df = df.reset_index(drop=True)

df.head(5)
# Out:
# 0  Tipo de Entidad                     Entidad Autorizada Compra  Venta  \
# 0  Bancos públicos                    Banco de Costa Rica  46000  47400
# 1              NaN           Banco Nacional de Costa Rica  45900  47300
# 2              NaN  Banco Popular y de Desarrollo Comunal  46100  47500
# 3  Bancos privados                Banco BAC San José S.A.  46000  47400
# 4              NaN                         Banco BCT S.A.  45700  47500
#
# 0 Diferencial Cambiario   Última Actualización
# 0                  1400  19/03/2026 08:32 p.m.
# 1                  1400  20/03/2026 08:35 a.m.
# 2                  1400  17/03/2026 01:37 p.m.
# 3                  1400  20/03/2026 08:29 a.m.
# 4                  1800  19/03/2026 12:54 p.m.

# %%
df.shape, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tipo de Entidad        7 non-null      object
#  1   Entidad Autorizada     37 non-null     object
#  2   Compra                 37 non-null     object
#  3   Venta                  37 non-null     object
#  4   Diferencial Cambiario  37 non-null     object
#  5   Última Actualización   37 non-null     object
# dtypes: object(6)
# memory usage: 1.9+ KB
# ((38, 6), None)

# %% [markdown]
# ## Parte 3
# - c) [15 puntos] Realizar limpieza y procesamiento de datos:
#     - Corregir problemas de encoding (caracteres como Ãľ, Ãś, etc.).
#     - Llenar valores NaN en Tipo de entidad usando `ffill()`.
#     - Convertir las columnas numéricas (Compra, Venta, Diferencial) dividiéndolas entre 100 para obtener el formato decimal correcto.
#
#     **Pista**: Los números vienen como enteros (p. ej., 49900) y deben convertirse a decimales (p. ej., 499.00).

# %%
df.columns
# Out:
# Index(['Tipo de Entidad', 'Entidad Autorizada', 'Compra', 'Venta',
#        'Diferencial Cambiario', 'Última Actualización'],
#       dtype='object', name=0)

# %%
# Revision de caracteres erroneos
def revision(df):
    for col in df:
        print(repr(df[col].iloc[0]))

revision(df)
# Out:
# 'Bancos públicos'
# 'Banco de Costa Rica'
# '46000'
# '47400'
# '1400'
# '19/03/2026 08:32 p.m.'

# %%
df.tail(1)
# Out:
# 0  Tipo de Entidad Entidad Autorizada Compra Venta Diferencial Cambiario  \
# 37             NaN                NaN    NaN   NaN                   NaN
#
# 0  Última Actualización
# 37                  NaN

# %%
# Se elimina la ultima columna del data frame que esta vacia
# df = df.drop(df.tail(1).index)
df.drop(df.tail(1).index, inplace=True)

# %%
df.head(6)
# Out:
# 0  Tipo de Entidad                     Entidad Autorizada Compra  Venta  \
# 0  Bancos públicos                    Banco de Costa Rica  46000  47400
# 1              NaN           Banco Nacional de Costa Rica  45900  47300
# 2              NaN  Banco Popular y de Desarrollo Comunal  46100  47500
# 3  Bancos privados                Banco BAC San José S.A.  46000  47400
# 4              NaN                         Banco BCT S.A.  45700  47500
# 5              NaN        Banco Cathay de Costa Rica S.A.  46000  47250
#
# 0 Diferencial Cambiario   Última Actualización
# 0                  1400  19/03/2026 08:32 p.m.
# 1                  1400  20/03/2026 08:35 a.m.
# 2                  1400  17/03/2026 01:37 p.m.
# 3                  1400  20/03/2026 08:29 a.m.
# 4                  1800  19/03/2026 12:54 p.m.
# 5                  1250  19/03/2026 12:57 p.m.

# %%
# se rellenan los llenar valores faltantes propagando la última observación válida hacia adelante
df = df.ffill()

# %%
df.head(10)
# Out:
# 0  Tipo de Entidad                     Entidad Autorizada Compra  Venta  \
# 0  Bancos públicos                    Banco de Costa Rica  46000  47400
# 1  Bancos públicos           Banco Nacional de Costa Rica  45900  47300
# 2  Bancos públicos  Banco Popular y de Desarrollo Comunal  46100  47500
# 3  Bancos privados                Banco BAC San José S.A.  46000  47400
# 4  Bancos privados                         Banco BCT S.A.  45700  47500
# 5  Bancos privados        Banco Cathay de Costa Rica S.A.  46000  47250
# 6  Bancos privados                              Banco CMB  45200  47600
# 7  Bancos privados      Banco Davivienda (Costa Rica) S.A  45700  47500
# 8  Bancos privados        Banco General (Costa Rica) S.A.  45700  47300
# 9  Bancos privados                     Banco Improsa S.A.  45800  47600
#
# 0 Diferencial Cambiario   Última Actualización
# 0                  1400  19/03/2026 08:32 p.m.
# 1                  1400  20/03/2026 08:35 a.m.
# 2                  1400  17/03/2026 01:37 p.m.
# 3                  1400  20/03/2026 08:29 a.m.
# 4                  1800  19/03/2026 12:54 p.m.
# 5                  1250  19/03/2026 12:57 p.m.
# 6                  2400  20/03/2026 09:34 a.m.
# 7                  1800  19/03/2026 02:01 p.m.
# 8                  1600  19/03/2026 12:54 p.m.
# 9                  1800  17/03/2026 11:21 a.m.

# %%
df.isna().sum()
# Out:
# 0
# Tipo de Entidad          0
# Entidad Autorizada       0
# Compra                   0
# Venta                    0
# Diferencial Cambiario    0
# Última Actualización     0
# dtype: int64

# %%
# columnas de object -> float | Compra, Venta y Diferencial Cambiario
for col in df.iloc[:, 2:5].columns:  
    df[col] = df[col].astype(float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tipo de Entidad        37 non-null     object
#  1   Entidad Autorizada     37 non-null     object
#  2   Compra                 37 non-null     float64
#  3   Venta                  37 non-null     float64
#  4   Diferencial Cambiario  37 non-null     float64
#  5   Última Actualización   37 non-null     object
# dtypes: float64(3), object(3)
# memory usage: 1.9+ KB

# %%
# for col in df2.iloc[:, 2:5].columns:        
#     df2[col] = (df2[col] / 100).round(2)

# %%
def to_decimal(df):        
    df2 = df.copy()
    df2.iloc[:, 2:5] = (df2.iloc[:, 2:5] / 100).round(2) # Compra, Venta y Diferencial Cambiario
    return df2

tc_ventanilla_bccr = to_decimal(df)
tc_ventanilla_bccr.head(5).sort_values('Compra', ascending=False)
# Out:
# 0  Tipo de Entidad                     Entidad Autorizada  Compra  Venta  \
# 2  Bancos públicos  Banco Popular y de Desarrollo Comunal   461.0  475.0
# 0  Bancos públicos                    Banco de Costa Rica   460.0  474.0
# 3  Bancos privados                Banco BAC San José S.A.   460.0  474.0
# 1  Bancos públicos           Banco Nacional de Costa Rica   459.0  473.0
# 4  Bancos privados                         Banco BCT S.A.   457.0  475.0
#
# 0  Diferencial Cambiario   Última Actualización
# 2                   14.0  17/03/2026 01:37 p.m.
# 0                   14.0  19/03/2026 08:32 p.m.
# 3                   14.0  20/03/2026 08:29 a.m.
# 1                   14.0  20/03/2026 08:35 a.m.
# 4                   18.0  19/03/2026 12:54 p.m.

# %% [markdown]
# ## Parte 4
# - d) [10 puntos] Guardar el resultado final en un archivo CSV llamado `tc_ventanilla_bccr.csv` con codificación UTF-8.

# %%
tc_ventanilla_bccr.to_csv("tc_ventanilla_bccr.csv", index=False, encoding="utf-8")
